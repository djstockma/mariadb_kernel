-- %% [markdown]
-- ## Test notebook for new added magic command

-- %%
use test;

-- %%
CREATE TABLE IF NOT EXISTS test_table (
    id INT AUTO_INCREMENT PRIMARY KEY,
    name VARCHAR(100),
    age INT
);
-- Out:
-- Query OK

-- %%
INSERT INTO test_table (name, age) VALUES ('Alice', 30);
INSERT INTO test_table (name, age) VALUES ('Bob', 25);
INSERT INTO test_table (name, age) VALUES ('Charlie', 35);
-- Out:
-- Query OK

-- %%
SELECT * FROM test_table;
-- Out:
-- <html><body><table border="1" style="margin-left: 0"><tr><th style="text-align:left;white-space:pre">id</th><th style="text-align:left;white-space:pre">name</th><th style="text-align:left;white-space:pre">age</th></tr><tr><td style="text-align:left;white-space:pre">1</td><td style="text-align:left;white-space:pre">Alice</td><td style="text-align:left;white-space:pre">30</td></tr><tr><td style="text-align:left;white-space:pre">2</td><td style="text-align:left;white-space:pre">Bob</td><td style="text-align:left;white-space:pre">25</td></tr><tr><td style="text-align:left;white-space:pre">3</td><td style="text-align:left;white-space:pre">Charlie</td><td style="text-align:left;white-space:pre">35</td></tr></table></body></html>
