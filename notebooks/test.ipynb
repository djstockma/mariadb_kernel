# %% [markdown]
# ## Test notebook for new added magic command

# %%
# %chatgpt input=riddle
# Out:
# UsageError: Line magic function `%chatgpt` not found.

# %%
# %chatgpt input="a funny riddle about dogs"
